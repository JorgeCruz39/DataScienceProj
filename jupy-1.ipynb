# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scile
datas=pd.read_csv("student-por.csv")

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
data['sex'].value_counts().plot(kind='bar',title="Female and Male Students across both schools", color=["hotpink",'#0fdbd9'])
plt.xticks(rotation=0, horizontalalignment="center")
# Out:
# (array([0, 1]), [Text(0, 0, 'F'), Text(1, 0, 'M')])

# %%
ax=data.groupby(['school', 'sex']).size().unstack().plot(kind='bar', stacked=True,color=["hotpink",'#0fdbd9'])
ax.set_xlabel("School")
ax.set_ylabel("# of students")
ax.set_title("Amounts of students ")
ax = plt.gca()
leg = ax.get_legend()
leg.legendHandles[0].set_color('hotpink')
leg.legendHandles[1].set_color('#0fdbd9')
plt.xticks(rotation=0, horizontalalignment="center")
# Out:
# (array([0, 1]), [Text(0, 0, 'GP'), Text(1, 0, 'MS')])

# %%
G1_Mean= data["G1"].mean()
G2_Mean= data["G2"].mean()
G3_Mean= data["G3"].mean()

# %%
palette = ['tab:pink','tab:blue']
sns.set_palette("bright")

# %%
sns.histplot(data=datas,x="G1",bins=20,palette=palette,kde=True,hue="sex",alpha=.8)
plt.axvline(x=G1_Mean,color='red',ls='--',lw=2.5)

# %%
sns.histplot(data=datas,x="G2",bins=20,palette=palette,kde=True,hue="sex",alpha=.8)
# Out:
# <AxesSubplot: xlabel='G2', ylabel='Count'>

# %%
sns.histplot(data=datas,x="G3",bins=20,palette=palette,kde=True,hue="sex",alpha=.8)
# Out:
# <AxesSubplot: xlabel='G3', ylabel='Count'>
